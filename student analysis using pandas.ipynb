# %%
import pandas as pd

# %%
student_data=pd.read_csv(r"C:\Users\91779\Downloads\StudentsPerformance.csv")

# %%
student_data.head(20)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %%
import numpy as np
np.set_printoptions(linewidth=110)

# %%
#adding a new cell to calculate percentage of studenta scored in math,reading,writing
sum1=student_data["sum"]=(student_data["math score"]+student_data["reading score"]+student_data["writing score"])/300

# %%
sum1
# Out:
# 0      0.726667
# 1      0.823333
# 2      0.926667
# 3      0.493333
# 4      0.763333
#          ...
# 995    0.940000
# 996    0.573333
# 997    0.650000
# 998    0.743333
# 999    0.830000
# Length: 1000, dtype: float64

# %%
student_data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
#student_percentage=student_percentage["Percentage"]=(student_percentage["sum"]*100)

# %%
student_data["percentage"]=(student_data["sum"])*100

# %%
student_data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
#take out all the males >90%
males=student_data.copy()
males.loc[males["percentage"]>90.00]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 104    male        group C                some college      standard
# 106  female        group D             master's degree      standard
# 114  female        group E           bachelor's degree      standard
# 121    male        group B          associate's degree      standard
# 122  female        group C                some college      standard
# 149    male        group E          associate's degree  free/reduced
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
# 229  female        group C                some college      standard
# 263  female        group E                 high school      standard
# 268  female        group D          associate's degree      standard
# ...

# %%
#take out all the males >35%
males_less50=student_data.copy()
males_less50.loc[males_less50["percentage"]<35.00]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 17   female        group B            some high school  free/reduced
# 59   female        group C            some high school  free/reduced
# 76     male        group E            some high school      standard
# 91     male        group C                 high school  free/reduced
# 145  female        group C                some college  free/reduced
# 211    male        group C                some college  free/reduced
# 327    male        group A                some college  free/reduced
# 338  female        group B            some high school  free/reduced
# 363  female        group D            some high school  free/reduced
# 466  female        group D          associate's degree  free/reduced
# 555  female        group C                some college  free/reduced
# 596    male        group B                 high school  free/reduced
# 601  female        group C                 high school      standard
# ...

# %%
#female percentage greater  than>90%
female_greater90=student_data.copy()
female_greater90.loc[female_greater90["percentage"]<90.00]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 994    male        group A                 high school      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
#data of female percentage less than 35%
female_lessthan35=student_data.copy()
female_lessthan35.loc[female_lessthan35["percentage"]<35.00]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 17   female        group B            some high school  free/reduced
# 59   female        group C            some high school  free/reduced
# 76     male        group E            some high school      standard
# 91     male        group C                 high school  free/reduced
# 145  female        group C                some college  free/reduced
# 211    male        group C                some college  free/reduced
# 327    male        group A                some college  free/reduced
# 338  female        group B            some high school  free/reduced
# 363  female        group D            some high school  free/reduced
# 466  female        group D          associate's degree  free/reduced
# 555  female        group C                some college  free/reduced
# 596    male        group B                 high school  free/reduced
# 601  female        group C                 high school      standard
# ...

# %%
#number of female candidates 
female_no=student_data.copy()
len(female_no.loc[female_no["gender"]=="female"])
# Out:
# 518

# %%
#number of males 
male_no=student_data.copy()
len(male_no.loc[male_no["gender"]=="male"])
# Out:
# 482

# %%
student_data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
parents=student_data.copy()
parents=len(parents.loc[parents["parental level of education"]=="bachelor's degree"])
parents
# Out:
# 118

# %%
parents.loc[parents["parental level of education"]=="bachelor's degree"]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 24     male        group D           bachelor's degree  free/reduced
# 27   female        group C           bachelor's degree      standard
# 60     male        group E           bachelor's degree  free/reduced
# 77     male        group A           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 916    male        group E           bachelor's degree      standard
# 933    male        group C           bachelor's degree  free/reduced
# 969  female        group B           bachelor's degree      standard
# 970  female        group D           bachelor's degree      standard
# 993  female        group D           bachelor's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
standard=student_data.copy()
standard.loc[standard["lunch"]=="standard"]
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 0    female        group B           bachelor's degree  standard
# 1    female        group C                some college  standard
# 2    female        group B             master's degree  standard
# 4      male        group C                some college  standard
# 5    female        group B          associate's degree  standard
# ..      ...            ...                         ...       ...
# 987    male        group E            some high school  standard
# 991  female        group B            some high school  standard
# 994    male        group A                 high school  standard
# 995  female        group E             master's degree  standard
# 998  female        group D                some college  standard
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# ...

# %%
len(standard.loc[standard["lunch"]=="standard"])
# Out:
# 645

# %%
free=student_data.copy()
len(free.loc[free["lunch"]=="free/reduced"])
# Out:
# 355

# %%
men_with_standard=student_data.copy()
men_with_standard.loc[(men_with_standard["lunch"]=="standard") & (men_with_standard["gender"]=="male")]
# Out:
#     gender race/ethnicity parental level of education     lunch  \
# 4     male        group C                some college  standard
# 10    male        group C          associate's degree  standard
# 11    male        group D          associate's degree  standard
# 13    male        group A                some college  standard
# 16    male        group C                 high school  standard
# ..     ...            ...                         ...       ...
# 981   male        group D            some high school  standard
# 982   male        group B            some high school  standard
# 985   male        group A                 high school  standard
# 987   male        group E            some high school  standard
# 994   male        group A                 high school  standard
#
#     test preparation course  math score  reading score  writing score  \
# 4                      none          76             78             75
# ...

# %%
len(men_with_standard.loc[(men_with_standard["lunch"]=="standard") & (men_with_standard["gender"]=="male")])
# Out:
# 316

# %%
best=student_data.loc[(student_data["test preparation course"]=="completed") & (student_data["percentage"]>90.00) & (student_data["gender"]=="male")]

# %%
len(student_data.loc[(student_data["test preparation course"]=="completed") & (student_data["percentage"]>90.00) & (student_data["gender"]=="male")])
# Out:
# 12

# %%
best
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 104   male        group C                some college      standard
# 121   male        group B          associate's degree      standard
# 149   male        group E          associate's degree  free/reduced
# 381   male        group C          associate's degree      standard
# 539   male        group A          associate's degree      standard
# 562   male        group C           bachelor's degree      standard
# 612   male        group C           bachelor's degree      standard
# 623   male        group A                some college      standard
# 625   male        group D                some college      standard
# 916   male        group E           bachelor's degree      standard
# 919   male        group B                some college      standard
# 934   male        group C          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
best.to_csv(r"C:\Users\91779\OneDrive\Desktop\data science\studentbest.csv")
